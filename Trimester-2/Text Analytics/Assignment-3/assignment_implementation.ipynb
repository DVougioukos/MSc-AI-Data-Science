# %% [markdown]
# ## **Assignment 3 - Exercise 1 - Text Classification with Recurrent Neural Networks**

# %% [markdown]
# <b><u>Contributor</u></b>: Dimitris Vougioukos - f3352411

# %% [markdown]
# The following is the implementation of the exercise 1 of the third assignment of the Text Analytics course on text classification with Recurrent Neural Networks (RNNs)

# %% [markdown]
# ### **Exercise 1**

# %% [markdown]
# Import and download some required packages

# %%
# Importing required libraries
import random
import nltk
import gensim.downloader as api
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import os
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import movie_reviews, stopwords
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
from torch.utils.data import DataLoader, TensorDataset
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import (
    precision_recall_curve,
    auc,
    classification_report,
    accuracy_score,
)
from tabulate import tabulate


# Downloading NLTK datasets
nltk.download("movie_reviews")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# Explore the `movie_reviews` dataset

# %%
# Getting all the file ids
file_ids = movie_reviews.fileids()

print(f"Five random file ids of the dataset:\n {random.sample(file_ids, 5)}\n")

# Getting the distinct classes
categories = movie_reviews.categories()


print(f"The distinct classes of the reviews:\n {categories} \n")
print(f"The number of positive reviews is: {len(movie_reviews.fileids('pos'))} \n")
print(f"The number of negative reviews is: {len(movie_reviews.fileids('neg'))}")
# Out:
# Five random file ids of the dataset:
#  ['pos/cv052_29378.txt', 'neg/cv165_2389.txt', 'pos/cv513_6923.txt', 'pos/cv712_22920.txt', 'neg/cv323_29633.txt']
#
# The distinct classes of the reviews:
#  ['neg', 'pos']
#
# The number of positive reviews is: 1000
#
# The number of negative reviews is: 1000

# %% [markdown]
# Retrieve the raw text of each review and its corresponding category

# %%
# Initializing two lists to keep the raw text of each review and its category
reviews_text = []
reviews_category = []

# Iterating over the review categories
for category in categories:

    # Iterating over the file ids of the current category
    for file_id in movie_reviews.fileids(category):

        # Updating the lists
        reviews_text.append(movie_reviews.raw(file_id))
        reviews_category.append(1 if category == "pos" else 0)

# %% [markdown]
# Pre-process the reviews

# %%
# Setting the stopwords
stopwords = stopwords.words("english")

# Initializing a lemmatizer
lemmatizer = WordNetLemmatizer()

# Initializing a list to keep the tokenized reviews
tokenized_reviews_text = []

# Iterating over the reviews
for review_text in reviews_text:

    # Initializing a list to keep the tokens of the current review
    tokenized_review_text = []

    # Getting the sentences of the current review
    sentences = sent_tokenize(review_text)

    # Iterating over the sentences
    for sentence in sentences:

        # Applying word level tokenization
        words = word_tokenize(sentence)

        # Iterating over the tokens/words
        for word in words:

            # Checking whether to keep or not the token
            if word.isalnum() and word not in stopwords:

                # Updating
                tokenized_review_text.append(lemmatizer.lemmatize(word.strip().lower()))

    # Updating
    tokenized_reviews_text.append(tokenized_review_text)

# Getting the average length of all the reviews
avg_review_length = int(
    round(
        sum(len(tokenized_review) for tokenized_review in tokenized_reviews_text)
        / len(tokenized_reviews_text),
        0,
    )
)

print(f"The average review length is: {avg_review_length} tokens")
# Out:
# The average review length is: 342 tokens

# %% [markdown]
# Split dataset into training, validation and test datasets

# %%
# Splitting the dataset into training and test datasets
reviews_training, reviews_test, categories_training, categories_test = (
    train_test_split(
        tokenized_reviews_text,
        reviews_category,
        test_size=0.2,
        random_state=42,
        stratify=reviews_category,
    )
)

# Splitting the training dataset into training and development datasets
reviews_training, reviews_validation, categories_training, categories_validation = (
    train_test_split(
        reviews_training,
        categories_training,
        test_size=0.3,
        random_state=42,
        stratify=categories_training,
    )
)

print(f"The number of reviews in the training dataset is: {len(reviews_training)}")
print(f"The number of reviews in the validation dataset is: {len(reviews_validation)}")
print(f"The number of reviews in the test dataset is: {len(reviews_test)}")

# Getting the average length of all the training reviews
avg_training_review_length = int(
    round(
        sum(len(review) for review in reviews_training)
        / len(reviews_training),
        0,
    )
)

print(f"\nThe average length of the training reviews is: {avg_training_review_length} tokens")
# Out:
# The number of reviews in the training dataset is: 1120
# The number of reviews in the validation dataset is: 480
# The number of reviews in the test dataset is: 400
#
# The average length of the training reviews is: 341 tokens

# %% [markdown]
# Download Word2Vec embeddings trained on Google news dataset

# %%
# Getting the Word2Vec embeddings
word2vec_embeddings = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %% [markdown]
# Get the average embedding from all the Word2Vec embeddings

# %%
# Computing the average of all the embeddings
avg_embedding = np.mean(word2vec_embeddings.vectors, axis=0)

# %% [markdown]
# Create a vocabulary using the training dataset

# %%
# Setting a CountVectorizer keeping the top 10000 tokens
count_vectorizer = CountVectorizer(max_features=10000)

# Getting the join of the tokens of each training review
joined_reviews_training = [" ".join(review) for review in reviews_training]

# Fitting the vectorizer
count_vectorizer.fit(joined_reviews_training)

# Getting the tokens/words
most_frequent_words = count_vectorizer.get_feature_names_out()

# Setting up the vocabulary with the padding and unknown tokens
vocabulary = {'PAD': 0, 'UNK': 1}

# Updating the vocabulary with the most frequent words and assigning to them an index
vocabulary.update({word: index for index, word in enumerate(most_frequent_words, start=2)})

# %% [markdown]
# Create the embedding matrix

# %%
# Setting the embedding matrix for all the words of the vocabulary
embedding_matrix = np.zeros((10002, 300))

# Assigning the average embedding as the embedding for the UNK token
embedding_matrix[1] = avg_embedding

# Iterating over all the words of the vocabulary
for word, index in vocabulary.items():

    # Checking for PAD or UNK tokens
    if index > 1:

        # # Checking whether there is a word2vec word embedding
        if word in word2vec_embeddings:

            # Assigning the word2vec embedding
            embedding_matrix[index] = word2vec_embeddings[word]

        else:

            # Assigning the average word2vec embedding
            embedding_matrix[index] = avg_embedding

# Deleting it for memory reasons
del word2vec_embeddings

# %% [markdown]
# Define a function to encode reviews based on vocabulary and maintain a predefined length for them

# %%
def encode_reviews(reviews, vocabulary, max_review_length):
    """
    Define a function to encode reviews based on vocabulary and maintain a
    predefined length for them.

    :param reviews: The reviews to be encoded.
    :param vocabulary: The vocabulary used to encode the reviews.
    :param max_review_length: The maximum length of the reviews.
    :return: The encoded reviews.
    """

    # Setting a list to keep the encoded reviews
    encoded_reviews = []

    # Iterating over the reviews
    for review in reviews:

        # Initializing a list to keep the encoded tokens of the current review
        encoded_review = []

        # Iterating over the tokens of the current review
        for token in review:

            # Checking whether the token is in the vocabulary
            if token in vocabulary:

                # Assigning the relevant vocabulary index
                encoded_review.append(vocabulary[token])

            else:

                # Assigning the index of the UNK token
                encoded_review.append(1)

        # Checking the length of the review
        if len(encoded_review) < max_review_length:

            # Adding padding (PAD) tokens
            encoded_review.extend([0] * (max_review_length - len(encoded_review)))

        elif len(encoded_review) > max_review_length:

            # Getting the first and second halfs
            first_half = max_review_length // 2
            second_half = max_review_length - first_half

            # Getting some tokens from the start and the end of the review
            encoded_review = (
                encoded_review[:first_half] + encoded_review[-second_half:]
            )

        # Updating
        encoded_reviews.append(encoded_review)

    return encoded_reviews

# %% [markdown]
# Enocde the reviews

# %%
# Encoding the reviews of the datasets
encoded_reviews_training = encode_reviews(reviews_training, vocabulary, avg_training_review_length)
encoded_reviews_validation = encode_reviews(reviews_validation, vocabulary, avg_training_review_length)
encoded_reviews_test = encode_reviews(reviews_test, vocabulary, avg_training_review_length)

# %% [markdown]
# Define a RNN classifier

# %%
class RNNClassifier(nn.Module):

    def __init__(
        self,
        vocabulary_size,
        embedding_dimension,
        hidden_dimension,
        rnn_type,
        embedding_matrix,
        freeze,
        stacks,
        attention_hidden_layers,
        attention_dropout_prob,
        attention_batch_normal,
        attention_layer_normal,
        mlp_head_hidden_layers,
        mlp_head_dropout_prob,
        mlp_head_batch_normal,
        mlp_head_layer_normal,
    ):
        """
        The constructor of the RNN classifier.

        :param vocabulary_size: The vocabulary size.
        :param embedding_dimension: The embedding dimension.
        :param hidden_dimension: The hidden dimension.
        :param rnn_type: The RNN type.
        :param embedding_matrix: The embedding matrix.
        :param freeze: Whether to freeze the embedding layer.
        :param stacks: The number of RNN layers.
        :param attention_hidden_layers: The hidden layers of the self-attention MLP.
        :param attention_dropout_prob: The dropout probability of the self-attention MLP
        :param attention_batch_normal: Whether to use batch normalization in the self-attention MLP.
        :param attention_layer_normal: Whether to use layer normalization in the self-attention MLP.
        :param mlp_head_hidden_layers: The hidden layers of the MLP head.
        :param mlp_head_dropout_prob: The dropout probability of the MLP head.
        :param mlp_head_batch_normal: Whether to use batch normalization in the MLP head.
        :param mlp_head_layer_normal: Whether to use layer normalization in the MLP head.
        :return: None
        """

        # Calling the constructor of the super class
        super(RNNClassifier, self).__init__()

        # Checking for pre-trained embeddings
        if embedding_matrix is not None:

            # Setting the embedding layer using pre-trained embeddings
            self.embedding_layer = nn.Embedding(
                vocabulary_size, embedding_dimension, padding_idx=0
            ).from_pretrained(embedding_matrix, freeze=freeze)

        else:

            # Setting a random embedding layer
            self.embedding_layer = nn.Embedding(
                vocabulary_size, embedding_dimension, padding_idx=0
            )

        # Setting the RNN model
        self.rnn = rnn_type(
            embedding_dimension,
            hidden_dimension,
            batch_first=True,
            num_layers=stacks,
            bidirectional=True,
        )

        # Setting the self-attention MLP
        self.attention_mlp = self.define_mlp(
            hidden_dimension * 2,
            attention_hidden_layers,
            1,
            attention_dropout_prob,
            attention_batch_normal,
            attention_layer_normal,
            "self-attention",
        )

        # Setting the MLP head
        self.mlp_head = self.define_mlp(
            hidden_dimension * 2,
            mlp_head_hidden_layers,
            1,
            mlp_head_dropout_prob,
            mlp_head_batch_normal,
            mlp_head_layer_normal,
            "mlp head",
        )


    def define_mlp(
        self,
        input_dimension,
        hidden_layers,
        output_dimension,
        dropout_prob,
        batch_normal,
        layer_normal,
        type,
    ):
        """
        This function is used to define a MLP with optional dropout, batch
        normalization, and layer normalization.

        :param input_dimension: The input dimension of the MLP.
        :param hidden_layers: The hidden layers of the MLP.
        :param output_dimension: The output dimension of the MLP.
        :param dropout_prob: The dropout probability.
        :param batch_normal: Whether to use batch normalization.
        :param layer_normal: Whether to use layer normalization.
        :param type: The type of the MLP.
        :return: The defined MLP.
        """

        # Setting a list keeping hidden layers parameters
        total_layers = []

        # Setting the dimension of the first layer (input layer)
        prev_layer_dimension = input_dimension

        # Checking whether there are hidden layers to add
        if hidden_layers:

            # Iterating over the hidden layers
            for hidden_layer in hidden_layers:

                # Adding the hidden layer with the specified dimension (number of neurons)
                total_layers.append(nn.Linear(prev_layer_dimension, hidden_layer))

                # Setting a ReLU activation function for the hidden layer's neurons
                total_layers.append(nn.ReLU())

                # Checking to add dropout or not
                if dropout_prob > 0:

                    # Adding dropout
                    total_layers.append(nn.Dropout(dropout_prob))

                # Checking to add batch normalization or not
                if batch_normal:

                    # Adding batch normalization
                    total_layers.append(nn.BatchNorm1d(hidden_layer))

                # Checking to add layer normalization or not
                if layer_normal:

                    # Adding layer normalization
                    total_layers.append(nn.LayerNorm(hidden_layer))

                # Updating the last layer's dimension
                prev_layer_dimension = hidden_layer

        # Adding the ouput layer
        total_layers.append(nn.Linear(prev_layer_dimension, output_dimension))

        # Checking the mlp type
        if type == "mlp head":

            # Setting a Sigmoid activation function for the output layer
            total_layers.append(nn.Sigmoid())

        return nn.Sequential(*total_layers)


    def forward(self, x):
        """
        The forward function of the RNN classifier.

        :param x: The input tensor.
        :return: The output tensor.
        """

        # Getting the embeddings of the words of the reviews in the batch
        embeddings = self.embedding_layer(x)

        # Getting all the states of the final RNN layer
        states, _ = self.rnn(embeddings)

        # Reshaping to (batch_size * review_length, hidden_dimension * 2)
        states_reshaped = states.reshape(-1, states.shape[2])

        # Computing the attention scores of all the states
        attention_scores = self.attention_mlp(states_reshaped)

        # Reshaping back to (batch_size, review_length, 1)
        attention_scores = attention_scores.reshape(states.shape[0], states.shape[1], -1)

        # Creating a padding mask to ensure padding tokens get zero attention
        padding_mask = (x == 0).unsqueeze(-1).float()

        # Applying padding mask
        attention_scores -= 100000 * padding_mask

        # Computing the softmax values of the attention scores
        attention_scores = torch.softmax(attention_scores, dim=1)

        # Computing the weighted sum of the states
        weighted_sum = torch.sum(states * attention_scores, dim=1)

        return self.mlp_head(weighted_sum)

# %% [markdown]
# Define a function to train a RNN classifier

# %%
def train_rnn_classifier(
    rnn_classifier, epochs, training_loader, validation_loader, learning_rate, classifier_index
):
    """
    This function is used to train an RNN classifier.

    :param rnn_classifier: The RNN classifier
    :param epochs: The number of epochs
    :param training_loader: The training loader
    :param validation_loader: The validation loader
    :param learning_rate: The learning rate of the optimizer
    :param classifier_index: The index of the current classifier
    :return: The training and validation losses and the path of the best classifier
    """

    # Initializing two lists to keep the training ans validation losses across epochs
    training_losses, validation_losses = [], []

    # Initializing a variable to keep the lowest validation loss across epochs
    best_validation_loss = float("inf")

    # Setting a variable to hold the path of the best classifier
    best_classifier_path = None

    # Setting the loss function
    criterion = nn.BCELoss()

    # Setting the optimizer
    optimizer = optim.Adam(rnn_classifier.parameters(), lr=learning_rate)

    # Setting the epochs patience before early stopping
    patience = 5

    # Initializing a variable counting the epochs until early stopping
    early_stopping_counter = 0

    # Iterating over the epochs
    for epoch in range(1, epochs + 1):

        # Setting the model in training mode
        rnn_classifier.train()

        # Initializing a varibable to keep the epoch's training loss
        training_loss = 0

        # Iterating over the training batches
        for train_reviews, train_categories in training_loader:

            # Initializing the optimizer
            optimizer.zero_grad()

            # Predicting
            predicted_train_categories = rnn_classifier(train_reviews)

            # Computing the criterion loss (function loss)
            criterion_loss = criterion(
                predicted_train_categories, train_categories.unsqueeze(1).float()
            )

            # Applying backpropagation - Computing loss gradients
            criterion_loss.backward()

            # Updating the weights
            optimizer.step()

            # Updating the training loss
            training_loss += criterion_loss.item()

        # Getting the final training loss of the epoch
        training_loss = training_loss / len(training_loader)

        # Updating
        training_losses.append(training_loss)

        # Setting the model in evaluation mode
        rnn_classifier.eval()

        # Initializing a varibable to keep the epoch's validation loss
        validation_loss = 0

        # Without using the gradient computations
        with torch.no_grad():

            # Iterating over the validation batches
            for val_reviews, val_categories in validation_loader:

                # Predicting
                predicted_val_categories = rnn_classifier(val_reviews)

                # Computing the loss
                criterion_loss = criterion(
                    predicted_val_categories, val_categories.unsqueeze(1).float()
                )

                # Updating the validation loss
                validation_loss += criterion_loss.item()

        # Getting the final validation loss of the epoch
        validation_loss = validation_loss / len(validation_loader)

        # Updating
        validation_losses.append(validation_loss)

        # Checking to show the current losses
        if epoch % 5 == 0:

            print(
                f"Epoch: {epoch} / {epochs} | Training Loss: {training_loss:.4f}, Validation Loss: {validation_loss:.4f}"
            )

        # Checking if we have a better validation loss
        if validation_loss < best_validation_loss:

            # Updating
            early_stopping_counter = 0

            # Updating best validation loss
            best_validation_loss = validation_loss

            # Checking whether a previous best model exists
            if best_classifier_path is not None:

                # Deleting
                os.remove(best_classifier_path)

            # Updating the new best classifier path
            best_classifier_path = (
                f"best_classifier_{classifier_index}_epoch_{epoch}.pth"
            )

            # Saving the best classifier
            torch.save(rnn_classifier.state_dict(), best_classifier_path)

        else:

            # Updating
            early_stopping_counter += 1

            # Checking if early stopping is going to be triggered
            if early_stopping_counter >= patience:

                print(f"\nEarly stopping at epoch {epoch}")

                break

    return training_losses, validation_losses, best_classifier_path

# %% [markdown]
# Define a function to compute the classification scores of a RNN classifier on a given dataset

# %%
def compute_classification_scores(ground_truth, category_predictions, prob_predictions):
    """
    This function is used to compute the classification scores of a RNN
    classifier on a given dataset.

    :param ground_truth: The actual categories
    :param category_predictions: The predicted categories
    :param prob_predictions: The predicted probabilities
    :return: The classification scores
    """

    # Computing the precision, recall and f1 scores
    classification_scores = classification_report(
        ground_truth,
        category_predictions,
        target_names=["neg", "pos"],
        output_dict=True,
        zero_division=0,
    )

    # Computing the precision-recall auc score for "pos" category
    precision_pos, recall_pos, _ = precision_recall_curve(
        ground_truth, prob_predictions
    )
    pr_auc_pos = auc(recall_pos, precision_pos)

    # Updating the scores
    classification_scores["pos"]["precision-recall-auc"] = pr_auc_pos

    # Computing the precision-recall auc score for "neg" category
    precision_neg, recall_neg, _ = precision_recall_curve(
        [1 - value for value in ground_truth],
        [1 - prob_prediction for prob_prediction in prob_predictions],
    )
    pr_auc_neg = auc(recall_neg, precision_neg)

    # Updating the scores
    classification_scores["neg"]["precision-recall-auc"] = pr_auc_neg

    # Computing the macro-average for the precision-recall auc score
    classification_scores["macro avg"]["precision-recall-auc"] = (
        pr_auc_pos + pr_auc_neg
    ) / 2

    return classification_scores

# %% [markdown]
# Define a function to evaluate a RNN classifier on a given dataset

# %%
def evaluate(classifier, dataset):
    """
    This function is used to evaluate a RNN classifier on a dataset.

    :param classifier: The RNN classifier
    :param dataset: The dataset to evaluate on
    :return: Classification scores
    """

    # Setting the model in evaluation mode
    classifier.eval()

    # Initializing two lists to keep the actual and predicted categories and the
    # corresponding model's probabilities
    ground_truth, predictions, probs = [], [], []

    # Without using the gradient computations
    with torch.no_grad():

        # Iterating over the dataset's batches
        for reviews, categories in dataset:

            # Predicting
            predicted_probs = classifier(reviews)

            # Computing the actual predictions using the threshold 0.5
            predicted_categories = (predicted_probs >= 0.5).int()

            # Updating the lists
            ground_truth.extend(categories.tolist())
            predictions.extend(predicted_categories.flatten().tolist())
            probs.extend(predicted_probs.flatten().tolist())

    # Computing the classification scores
    classification_scores = compute_classification_scores(
        ground_truth, predictions, probs
    )

    return classification_scores

# %% [markdown]
# Create the required tensor datasets

# %%
# Checking if GPU is avalilable
if torch.cuda.is_available():

    # Setting the GPU as computing device
    device = torch.device("cuda")

else:

    # Setting the CPU as computing device
    device = torch.device("cpu")

# Creating PyTorch tensors
reviews_training_tensor = torch.tensor(encoded_reviews_training, dtype=torch.long).to(device)
categories_training_tensor = torch.tensor(categories_training, dtype=torch.long).to(device)
reviews_validation_tensor = torch.tensor(encoded_reviews_validation, dtype=torch.long).to(device)
categories_validation_tensor = torch.tensor(categories_validation, dtype=torch.long).to(device)
reviews_test_tensor = torch.tensor(encoded_reviews_test, dtype=torch.long).to(device)
categories_test_tensor = torch.tensor(categories_test, dtype=torch.long).to(device)
embedding_matrix_tensor = torch.tensor(embedding_matrix, dtype=torch.float32).to(device)

# Converting to tensor datasets
training_dataset = TensorDataset(
    reviews_training_tensor, categories_training_tensor
)
validation_dataset = TensorDataset(
    reviews_validation_tensor, categories_validation_tensor
)
test_dataset = TensorDataset(
    reviews_test_tensor, categories_test_tensor
)

# Creating DataLoaders
training_loader = DataLoader(
    training_dataset, batch_size=128, shuffle=True
)
validation_loader = DataLoader(
    validation_dataset, batch_size=128, shuffle=False
)
test_loader = DataLoader(
    test_dataset, batch_size=128, shuffle=False
)

# %% [markdown]
# Train and evaluate various RNN text classifiers

# %%
# Setting a list to keep the results from the training process of the classifiers
training_results = {}

# Setting the number of epochs
epochs = 30

# Setting various parameters for the rnn model
rnn_parameters = [
    [nn.RNN, None, True, 2, "RNN - No Pre-Trained Embeddings - Freeze - 2 Layers"],
    [nn.LSTM, embedding_matrix_tensor, True, 2, "LSTM - Pre-Trained Embeddings - Freeze - 2 Layers"],
    [nn.LSTM, None, True, 3, "LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers"],
    [nn.GRU, embedding_matrix_tensor, True, 3, "GRU - Pre-Trained Embeddings - Freeze - 3 Layers"],
    [nn.GRU, None, True, 2, "GRU - No Pre-Trained Embeddings - Freeze - 2 Layers"],
]

# Setting various parameters for the self-attention mlp
attention_mlp_parameters = [
    [None, 0, False, False, "No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization"],
    [[32, 16], 0.2, True, False, "Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization"],
]

# Setting various parameters for the mlp head
mlp_head_parameters = [
    [None, 0, False, False, "No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization"],
    [[32, 16], 0.2, True, False, "Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization"],
]


# Setting a counter
classifier_count = 1

# Iterating over the rnn pramaters
for rnn_parameter in rnn_parameters:

    # Iterating over the attention mlp parameters
    for attention_mlp_parameter in attention_mlp_parameters:

        # Iterating over the mlp head parameters
        for mlp_head_parameter in mlp_head_parameters:

            # Setting the name of the current classifier
            classifier_name = f"Classifier {classifier_count} - RNN Layer: ({rnn_parameter[4]}) - Attention MLP Layer: ({attention_mlp_parameter[4]}) - MLP Head Layer: ({mlp_head_parameter[4]})"

            # Initializing the classifier/model
            rnn_classifier = (
                RNNClassifier(
                    len(vocabulary),
                    300,
                    32,
                    rnn_parameter[0],
                    rnn_parameter[1],
                    rnn_parameter[2],
                    rnn_parameter[3],
                    attention_mlp_parameter[0],
                    attention_mlp_parameter[1],
                    attention_mlp_parameter[2],
                    attention_mlp_parameter[3],
                    mlp_head_parameter[0],
                    mlp_head_parameter[1],
                    mlp_head_parameter[2],
                    mlp_head_parameter[3],
                )
                .float()
                .to(device)
            )

            print(f"Training Process of {classifier_name}\n")

            # Training
            training_losses, validation_losses, best_classifier_path = (
                train_rnn_classifier(
                    rnn_classifier,
                    epochs,
                    training_loader,
                    validation_loader,
                    0.001,
                    classifier_count,
                )
            )

            print(f"\nEvaluation Process of {classifier_name}")

            print("\n----------------------------------------\n")

            # Loading the best model
            rnn_classifier.load_state_dict(
                torch.load(best_classifier_path, weights_only=False)
            )

            # Evaluating and keeping all the results
            training_results[f"classifier_{classifier_count}"] = {
                "training_losses": training_losses,
                "validation_losses": validation_losses,
                "best_classifier_path": best_classifier_path,
                "training_scores": evaluate(rnn_classifier, training_loader),
                "validation_scores": evaluate(rnn_classifier, validation_loader),
                "test_scores": evaluate(rnn_classifier, test_loader),
            }

            # Updating
            classifier_count += 1
# Out:
# Training Process of Classifier 1 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5926, Validation Loss: 0.6148
# Epoch: 10 / 30 | Training Loss: 0.0946, Validation Loss: 0.7289
#
# Early stopping at epoch 12
#
# Evaluation Process of Classifier 1 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 2 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5404, Validation Loss: 0.6452
# Epoch: 10 / 30 | Training Loss: 0.2051, Validation Loss: 0.5399
#
# Early stopping at epoch 14
#
# Evaluation Process of Classifier 2 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 3 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5451, Validation Loss: 0.5918
# Epoch: 10 / 30 | Training Loss: 0.0441, Validation Loss: 0.7111
#
# Early stopping at epoch 11
#
# Evaluation Process of Classifier 3 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 4 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5878, Validation Loss: 0.6707
# Epoch: 10 / 30 | Training Loss: 0.2649, Validation Loss: 0.5740
#
# Early stopping at epoch 14
#
# Evaluation Process of Classifier 4 - RNN Layer: (RNN - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 5 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.0728, Validation Loss: 0.5442
#
# Early stopping at epoch 9
#
# Evaluation Process of Classifier 5 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 6 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.1738, Validation Loss: 0.5213
# Epoch: 10 / 30 | Training Loss: 0.0879, Validation Loss: 0.3490
# Epoch: 15 / 30 | Training Loss: 0.0541, Validation Loss: 0.3690
#
# Early stopping at epoch 17
#
# Evaluation Process of Classifier 6 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 7 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.0783, Validation Loss: 0.4389
# Epoch: 10 / 30 | Training Loss: 0.0055, Validation Loss: 0.4668
#
# Early stopping at epoch 11
#
# Evaluation Process of Classifier 7 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 8 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.1813, Validation Loss: 0.5335
# Epoch: 10 / 30 | Training Loss: 0.0894, Validation Loss: 0.3528
# Epoch: 15 / 30 | Training Loss: 0.0554, Validation Loss: 0.3656
#
# Early stopping at epoch 15
#
# Evaluation Process of Classifier 8 - RNN Layer: (LSTM - Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 9 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.4831, Validation Loss: 0.5483
# Epoch: 10 / 30 | Training Loss: 0.0646, Validation Loss: 0.7348
#
# Early stopping at epoch 10
#
# Evaluation Process of Classifier 9 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 10 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5222, Validation Loss: 0.6641
# Epoch: 10 / 30 | Training Loss: 0.1693, Validation Loss: 0.5220
#
# Early stopping at epoch 14
#
# Evaluation Process of Classifier 10 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 11 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5190, Validation Loss: 0.7002
# Epoch: 10 / 30 | Training Loss: 0.0441, Validation Loss: 0.8135
#
# Early stopping at epoch 13
#
# Evaluation Process of Classifier 11 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 12 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.4957, Validation Loss: 0.6655
# Epoch: 10 / 30 | Training Loss: 0.1728, Validation Loss: 0.4817
# Epoch: 15 / 30 | Training Loss: 0.0850, Validation Loss: 0.4984
#
# Early stopping at epoch 15
#
# Evaluation Process of Classifier 12 - RNN Layer: (LSTM - No Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 13 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.0338, Validation Loss: 0.3861
#
# Early stopping at epoch 9
#
# Evaluation Process of Classifier 13 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 14 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.2553, Validation Loss: 0.4614
# Epoch: 10 / 30 | Training Loss: 0.1190, Validation Loss: 0.3584
# Epoch: 15 / 30 | Training Loss: 0.0743, Validation Loss: 0.3478
# Epoch: 20 / 30 | Training Loss: 0.0513, Validation Loss: 0.3486
#
# Early stopping at epoch 21
#
# Evaluation Process of Classifier 14 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 15 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.0155, Validation Loss: 0.4404
#
# Early stopping at epoch 9
#
# Evaluation Process of Classifier 15 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 16 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.2094, Validation Loss: 0.4276
# Epoch: 10 / 30 | Training Loss: 0.1058, Validation Loss: 0.3570
#
# Early stopping at epoch 14
#
# Evaluation Process of Classifier 16 - RNN Layer: (GRU - Pre-Trained Embeddings - Freeze - 3 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 17 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5432, Validation Loss: 0.5913
# Epoch: 10 / 30 | Training Loss: 0.0181, Validation Loss: 0.5774
#
# Early stopping at epoch 13
#
# Evaluation Process of Classifier 17 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 18 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.4807, Validation Loss: 0.6112
# Epoch: 10 / 30 | Training Loss: 0.1567, Validation Loss: 0.5219
#
# Early stopping at epoch 14
#
# Evaluation Process of Classifier 18 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 19 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.4043, Validation Loss: 0.6319
# Epoch: 10 / 30 | Training Loss: 0.0153, Validation Loss: 0.9491
#
# Early stopping at epoch 11
#
# Evaluation Process of Classifier 19 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (No Hidden Layers - No Dropout - No Batch Normalization - No Layer Normalization)
#
# ----------------------------------------
#
# Training Process of Classifier 20 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# Epoch: 5 / 30 | Training Loss: 0.5206, Validation Loss: 0.7063
# Epoch: 10 / 30 | Training Loss: 0.1682, Validation Loss: 0.5473
# Epoch: 15 / 30 | Training Loss: 0.0701, Validation Loss: 0.5405
#
# Early stopping at epoch 16
#
# Evaluation Process of Classifier 20 - RNN Layer: (GRU - No Pre-Trained Embeddings - Freeze - 2 Layers) - Attention MLP Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization) - MLP Head Layer: (Hidden Layers: [32, 16] - 0.2 Dropout - Batch Normalization - No Layer Normalization)
#
# ----------------------------------------

# %% [markdown]
# Show loss in training and validation data at all epochs for all RNN classifiers

# %%
# Creating a figure with 4 rows and 5 columns
fig, axes = plt.subplots(4, 5, figsize=(35, 20))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterating over the training results of the classifiers
for key, value in training_results.items():

    # Getting the current plot
    ax = axes[int(key.split("_")[1]) - 1]

    # Plotting the lines
    ax.plot(
        value["training_losses"],
        label="Training Loss",
        linestyle="-",
        alpha=0.8,
        color="blue",
    )
    ax.plot(
        value["validation_losses"],
        label="Validation Loss",
        linestyle="--",
        color="grey",
    )

    # Setting plot parameters
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Loss")
    ax.set_xticks(list(range(epochs)))
    ax.set_title(key)
    ax.legend()
    ax.grid(True, which="both", linestyle="--", linewidth=0.8, alpha=0.4)

# Adjusting the layout and showing the plots
plt.tight_layout()
plt.show()

# %%
print(
    f"""
      Best validation loss for classifier_6: {min(enumerate(training_results['classifier_6']['validation_losses'], start=1), key=lambda x: x[1])}
      Best validation loss for classifier_8: {min(enumerate(training_results['classifier_8']['validation_losses'], start=1), key=lambda x: x[1])}
      Best validation loss for classifier_13: {min(enumerate(training_results['classifier_13']['validation_losses'], start=1), key=lambda x: x[1])}
      Best validation loss for classifier_14: {min(enumerate(training_results['classifier_14']['validation_losses'], start=1), key=lambda x: x[1])}
      Best validation loss for classifier_16: {min(enumerate(training_results['classifier_16']['validation_losses'], start=1), key=lambda x: x[1])}
    """
)
# Out:
#       Best validation loss for classifier_6: (12, 0.3430054932832718)
#       Best validation loss for classifier_8: (10, 0.3527969419956207)
#       Best validation loss for classifier_13: (4, 0.3822796046733856)
#       Best validation loss for classifier_14: (16, 0.34678252786397934)
#       Best validation loss for classifier_16: (9, 0.3523254990577698)

# %% [markdown]
# After testing multiple RNN classifiers with different parameter values and text representations and analyzing the training loss and validation loss curves according to the above plots, classifier_6 emerged as the best model, achieving a validation loss of 0.343 at epoch 12, slightly lower than other classifiers with good performance

# %% [markdown]
# Display the classification scores of the best RNN classifier on all datasets (training, validation, test)

# %%
# Creating the first level of headers
table_headers_level_1 = [
    "",
    "\033[1mTraining Dataset\033[0m",
    "",
    "",
    "",
    "\033[1mValidation Dataset\033[0m",
    "",
    "",
    "",
    "\033[1mTest Dataset\033[0m",
    "",
    "",
    "",
]

# Creating the second level of headers
table_headers_level_2 = [
    "",
    "\033[1mPrecision\033[0m",
    "\033[1mRecall\033[0m",
    "\033[1mf1-Score\033[0m",
    "\033[1mPrecission-Recall AUC Score\033[0m",
    "\033[1mPrecision\033[0m",
    "\033[1mRecall\033[0m",
    "\033[1mf1-Score\033[0m",
    "\033[1mPrecission-Recall AUC Score\033[0m",
    "\033[1mPrecision\033[0m",
    "\033[1mRecall\033[0m",
    "\033[1mf1-Score\033[0m",
    "\033[1mPrecission-Recall AUC Score\033[0m",
]

# Creating the table values
table_data = [
    [
        "neg",
        round(training_results["classifier_6"]["training_scores"]["neg"]["precision"], 4),
        round(training_results["classifier_6"]["training_scores"]["neg"]["recall"], 4),
        round(training_results["classifier_6"]["training_scores"]["neg"]["f1-score"], 4),
        round(training_results["classifier_6"]["training_scores"]["neg"]["precision-recall-auc"], 4),
        round(training_results["classifier_6"]["validation_scores"]["neg"]["precision"], 4),
        round(training_results["classifier_6"]["validation_scores"]["neg"]["recall"], 4),
        round(training_results["classifier_6"]["validation_scores"]["neg"]["f1-score"], 4),
        round(training_results["classifier_6"]["validation_scores"]["neg"]["precision-recall-auc"], 4),
        round(training_results["classifier_6"]["test_scores"]["neg"]["precision"], 4),
        round(training_results["classifier_6"]["test_scores"]["neg"]["recall"], 4),
        round(training_results["classifier_6"]["test_scores"]["neg"]["f1-score"], 4),
        round(training_results["classifier_6"]["test_scores"]["neg"]["precision-recall-auc"], 4),
    ],
    [
        "pos",
        round(training_results["classifier_6"]["training_scores"]["pos"]["precision"], 4),
        round(training_results["classifier_6"]["training_scores"]["pos"]["recall"], 4),
        round(training_results["classifier_6"]["training_scores"]["pos"]["f1-score"], 4),
        round(training_results["classifier_6"]["training_scores"]["pos"]["precision-recall-auc"], 4),
        round(training_results["classifier_6"]["validation_scores"]["pos"]["precision"], 4),
        round(training_results["classifier_6"]["validation_scores"]["pos"]["recall"], 4),
        round(training_results["classifier_6"]["validation_scores"]["pos"]["f1-score"], 4),
        round(training_results["classifier_6"]["validation_scores"]["pos"]["precision-recall-auc"], 4),
        round(training_results["classifier_6"]["test_scores"]["pos"]["precision"], 4),
        round(training_results["classifier_6"]["test_scores"]["pos"]["recall"], 4),
        round(training_results["classifier_6"]["test_scores"]["pos"]["f1-score"], 4),
        round(training_results["classifier_6"]["test_scores"]["pos"]["precision-recall-auc"], 4),
    ],
    [
        "macro-average",
        round(training_results["classifier_6"]["training_scores"]["macro avg"]["precision"], 4),
        round(training_results["classifier_6"]["training_scores"]["macro avg"]["recall"], 4),
        round(training_results["classifier_6"]["training_scores"]["macro avg"]["f1-score"], 4),
        round(training_results["classifier_6"]["training_scores"]["macro avg"]["precision-recall-auc"], 4),
        round(training_results["classifier_6"]["validation_scores"]["macro avg"]["precision"], 4),
        round(training_results["classifier_6"]["validation_scores"]["macro avg"]["recall"], 4),
        round(training_results["classifier_6"]["validation_scores"]["macro avg"]["f1-score"], 4),
        round(training_results["classifier_6"]["validation_scores"]["macro avg"]["precision-recall-auc"], 4),
        round(training_results["classifier_6"]["test_scores"]["macro avg"]["precision"], 4),
        round(training_results["classifier_6"]["test_scores"]["macro avg"]["recall"], 4),
        round(training_results["classifier_6"]["test_scores"]["macro avg"]["f1-score"], 4),
        round(training_results["classifier_6"]["test_scores"]["macro avg"]["precision-recall-auc"], 4),
    ],
]

# Showing the classification scores

print(f"\033[1m{'Classification Scores':^200}\033[0m")
print()
print(
    tabulate(
        [table_headers_level_2] + table_data,
        headers=table_headers_level_1,
        tablefmt="rounded_grid",
    )
)
# Out:
#                                                                                          Classification Scores
#
# ╭───────────────┬────────────────────┬────────┬──────────┬─────────────────────────────┬──────────────────────┬────────┬──────────┬─────────────────────────────┬────────────────┬────────┬──────────┬─────────────────────────────╮
# │               │ Training Dataset   │        │          │                             │ Validation Dataset   │        │          │                             │ Test Dataset   │        │          │                             │
# ├───────────────┼────────────────────┼────────┼──────────┼─────────────────────────────┼──────────────────────┼────────┼──────────┼─────────────────────────────┼────────────────┼────────┼──────────┼─────────────────────────────┤
# │               │ Precision          │ Recall │ f1-Score │ Precission-Recall AUC Score │ Precision            │ Recall │ f1-Score │ Precission-Recall AUC Score │ Precision      │ Recall │ f1-Score │ Precission-Recall AUC Score │
# ├───────────────┼────────────────────┼────────┼──────────┼─────────────────────────────┼──────────────────────┼────────┼──────────┼─────────────────────────────┼────────────────┼────────┼──────────┼─────────────────────────────┤
# │ neg           │ 1.0                │ 1.0    │ 1.0      │ 1.0                         │ 0.8692               │ 0.8583 │ 0.8637   │ 0.9304                      │ 0.8511         │ 0.8    │ 0.8247   │ 0.9143                      │
# ├───────────────┼────────────────────┼────────┼──────────┼─────────────────────────────┼──────────────────────┼────────┼──────────┼─────────────────────────────┼────────────────┼────────┼──────────┼─────────────────────────────┤
# │ pos           │ 1.0                │ 1.0    │ 1.0      │ 1.0                         │ 0.8601               │ 0.8708 │ 0.8654   │ 0.9093                      │ 0.8113         │ 0.86   │ 0.835    │ 0.9135                      │
# ├───────────────┼────────────────────┼────────┼──────────┼─────────────────────────────┼──────────────────────┼────────┼──────────┼─────────────────────────────┼────────────────┼────────┼──────────┼─────────────────────────────┤
# │ macro-average │ 1.0                │ 1.0    │ 1.0      │ 1.0                         │ 0.8646               │ 0.8646 │ 0.8646   │ 0.9198                      │ 0.8312         │ 0.83   │ 0.8298   │ 0.9139                      │
# ╰───────────────┴────────────────────┴────────┴──────────┴─────────────────────────────┴──────────────────────┴────────┴──────────┴─────────────────────────────┴────────────────┴────────┴──────────┴─────────────────────────────╯
