# %% [markdown]
# ## **Quality Detector**

# %% [markdown]
# The following is the implementation of the task 1 and task 2. To execute it you should have a valid OpenAI API key.

# %% [markdown]
# ### **Task 1**

# %% [markdown]
# Import required Python libraries and download the Wordnet dictionary

# %%
# Importing some packages
from SPARQLWrapper import SPARQLWrapper, JSON
from openai import OpenAI
import nltk
from nltk.corpus import wordnet as wn
import spacy
import pandas as pd
from IPython.display import display
import numpy as np

# Download 'Wordnet' dictionary
nltk.download("wordnet")

# Load SpaCy model
model = spacy.load("en_core_web_sm")

# %% [markdown]
# Define relevant functions

# %%
def check_ambiguity_llm_approach(name, openai_key):
    """
    This function used to check if a name (class or property) is ambiguous or not
    using the ChatGPT LLM and especially the gpt-4o-mini model of it.

    :param name: The name to check
    :param openai_key: The OpenAI key to access the corresponding API
    :return: If it is ambiguous or not together with a explanation of that
    """

    # Setting up the content of the 'system' role
    system_content = f"""
    You are an system that helps assess the ambiguity of a term. Your job is to determine whether a given term is ambiguous or not.\n\
    \n\
    Some cases to help you understand when a term is ambiguous or not:\n\
        - A term is ambiguous when it has multiple meanings or it is uncertain (e.g., "bat" can refer to an animal or a piece of sports equipment.).\n\
        - A term is ambiguous when its meaning changes depending on the context in which it is used (e.g., "scale" can mean a musical scale in music, a device for weighing in measurement, or even a pattern on fish skin in biology.).\n\
        - A term is ambiguous when it has different meanings in different fields or industries (e.g., In sports, "run" refers to moving quickly on foot and in programming, "run" means to execute a program or script.). 
    \n\
    Important Instructions:\n\
        - Return the word "Yes" if the term is ambiguous or the word "No" if it is not and also a sentence explaining why it is ambiguous or not and always include the term to know what it refers to.
    """

    # Setting up the content of the 'user' role
    user_content = f"""
        Term: {name}\n\
        Is the given term ambiguous or not?
    """

    # Requesting
    completion = openai_key.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0,
        messages=[
            {"role": "system", "content": system_content},
            {"role": "user", "content": user_content},
        ],
    )

    return completion.choices[0].message.content


def check_ambiguity_dictionary_approach(name):
    """
    This function used to check if a name (class or property) is ambiguous or not
    using the Wordnet dictionary. It first checks if the whole name has senses
    otherwise checks the ambiguity of each it's words.

    :param name: The name to check
    :return: The word 'Ambiguous' or 'Non-Ambiguous'
    """

    # Getting the tokens of the name
    tokens = model(name)
    
    # Checking the number of tokens/words
    if len(tokens) == 1:

        # Finding the senses
        name_senses = wn.synsets(name)
        total_name_senses = len(name_senses)
        
        # Checking if it is ambiguous or not and return respectively
        if total_name_senses == 1:

            return {name: total_name_senses},"Non-Ambiguous"
        
        else:

            return {name: total_name_senses}, "Ambiguous"

    else:

        # Preprocessing
        tokens = [token.lower_ for token in tokens if token.is_alpha or token.is_digit]

        # Getting the name where the words are separated by underscore or space
        name_with_undersore = "_".join(tokens)
        name_with_space = " ".join(tokens)

        # Finding the senses for both versions of name
        name_senses_1 = wn.synsets(name_with_undersore)
        total_name_senses_1 = len(name_senses_1)
        name_senses_2 = wn.synsets(name_with_space)
        total_name_senses_2 = len(name_senses_2)

        # Checking if the name with underscores has at least one sence
        if total_name_senses_1 > 0:

            # Checking if it is ambiguous or not and return respectively
            if total_name_senses_1 == 1:

                return {name: total_name_senses_1},"Non-Ambiguous"
            else:

                return {name: total_name_senses_1}, "Ambiguous"

        # Checking if the name with spaces has at least one sense
        elif total_name_senses_2 > 0:

            # Checking if it is ambiguous or not and return respectively
            if total_name_senses_2 == 1:

                return {name: total_name_senses_2},"Non-Ambiguous"
            else:

                return {name: total_name_senses_2}, "Ambiguous"

        else:

            # Defining the dictionary to store the number
            # of senses for each token
            ambiguities = {}

            # Iterating through the tokens of the name
            for token in tokens:
                
                # Finding the senses of the token and
                # storing the number of them into the dictionary
                token_senses = wn.synsets(token)
                ambiguities[token] = len(token_senses)
            
            # Checking if it is ambiguous or not and return respectively
            if all(value == 1 for value in ambiguities.values()):

                return ambiguities, "Non-Ambiguous"

            else:

                return ambiguities, "Ambiguous"


def get_class_names(sparql):
    """
    This function used to find and return the names of all the classes in the DBPedia knowledge graph.

    :param sparql: 'SPARQLWrapper' object
    :return: The class names
    """

    # Setting up the query
    sparql.setQuery(
        """
        SELECT 
            DISTINCT (STR(?name) AS ?className)
        WHERE {
            # ?classId rdf:type owl:Class .
            OPTIONAL {
                # ?classId rdfs:label ?name .
                FILTER(LANG(?name) = "en")
            }
        }
        LIMIT 50
    """
    )

    # Executing the query
    query_results = sparql.query().convert()

    return query_results["results"]["bindings"]


def get_property_names(sparql):
    """
    This function used to find and return the names of all the properties in the DBPedia knowledge graph.

    :param sparql: 'SPARQLWrapper' object
    :return: The property names
    """

    # Setting up the query
    sparql.setQuery(
        """
        SELECT 
            DISTINCT (STR(?name) AS ?propertyName)
        WHERE {
            # ?propertyId rdf:type rdf:Property .
            OPTIONAL {
                # ?propertyId rdfs:label ?name .
                FILTER(LANG(?name) = "en")
            }
        }
        LIMIT 50
    """
    )

    # Executing the query
    query_results = sparql.query().convert()

    return query_results["results"]["bindings"]

# %% [markdown]
# Connect to the OpenAI API

# %%
# Connecting to OpenAI API
openai_key = OpenAI(
    api_key="Here place your OpenAI API key"
)

# %% [markdown]
# Access the DBPedia endpoint

# %%
# SPARQL endpoint of DBPedia
sparql_endpoint = "https://dbpedia.org/sparql"

# Setting up the 'SPARQLWrapper' object based on the DBPedia endpoint
sparql = SPARQLWrapper(sparql_endpoint)

# Defining the format of the queries results
sparql.setReturnFormat(JSON)

# %% [markdown]
# - #### **Quality Aassessment on Class Names**

# %% [markdown]
# Obtain the class names

# %%
# Getting the class names
class_names = get_class_names(sparql)

# Creating a dictionary to compare the results between the approaches
class_ambiguity_comparison = {class_name["className"]["value"]:{} for class_name in class_names}

# %% [markdown]
# Check which class names are ambiguous or not using ChatGPT

# %%
# Iterating through the names
for class_name in class_names:

    # Requesting
    response = check_ambiguity_llm_approach(
        class_name["className"]["value"],
        openai_key,
    )

    # Updating
    class_ambiguity_comparison[class_name["className"]["value"]]["llm"] = (
        "Ambiguous" if "Yes" in response else "Non-Ambiguous"
    )

    print(response)
# Out:
# Yes, the term "company" is ambiguous because it can refer to a business organization in a commercial context, or it can mean companionship or a group of people gathered together in a social context.
# Yes, the term "activity" is ambiguous because it can refer to various types of actions or tasks in different contexts, such as physical exercise, a specific event or project in a business setting, or even a recreational pastime.
# Yes, the term "name" is ambiguous because it can refer to a person's name, a brand name, a title of a work, or even a designation for a specific object or concept, depending on the context in which it is used.
# No, the term "person" is not ambiguous because it generally refers to an individual human being and does not have multiple meanings or interpretations in common usage.
# Yes, the term "actor" is ambiguous because it can refer to a person who performs in films, television, or theater, but it can also refer to a participant in a particular role within a system or process, such as in business or computer science contexts.
# Yes, the term "place" is ambiguous because it can refer to a physical location, a position in a ranking or competition, or even a concept of setting or context in various discussions.
# Yes, the term "publisher" is ambiguous because it can refer to a company or individual that publishes books, magazines, or other content, but it can also refer to a software publisher that distributes software products. The meaning changes depending on the context in which it is used.
# Yes, the term "genre" is ambiguous because it can refer to different categories in various fields such as literature, music, film, and art, each with its own specific classifications and meanings.
# Yes, the term "language" is ambiguous because it can refer to a system of communication used by humans (like English or Spanish), a programming language used in computer science (like Python or Java), or even a form of non-verbal communication (like body language or sign language), depending on the context in which it is used.
# Yes, the term "department" is ambiguous because it can refer to different organizational units within a company, such as the marketing department or human resources department, as well as to divisions within government or educational institutions, like the Department of Education or a university department.
# No, the term "software" is not ambiguous because it specifically refers to computer programs and applications, and its meaning does not change across different contexts or fields.
# Yes, the term "school" is ambiguous because it can refer to an educational institution where students learn, but it can also refer to a group of fish swimming together, depending on the context in which it is used.
# Yes, the term "type" is ambiguous because it can refer to different meanings in various contexts, such as a category of things (e.g., "type of fruit"), a classification in programming (e.g., "data type"), or even a method of printing (e.g., "type on a typewriter").
# No, the term "non-profit organisation" is not ambiguous because it has a specific meaning that refers to an organization that operates for purposes other than making a profit, typically focusing on social, educational, or charitable goals.
# Yes, the term "agent" is ambiguous because it can refer to a person who acts on behalf of another (such as a real estate agent), a software program that performs tasks autonomously (like an intelligent agent in AI), or even a chemical agent in scientific contexts, among other meanings.
# No, the term "biomolecule" is not ambiguous because it specifically refers to any molecule that is produced by living organisms, including proteins, nucleic acids, carbohydrates, and lipids. Its meaning is clear and consistent across biological and biochemical contexts.
# Yes, the term "broadcaster" is ambiguous because it can refer to a person or organization that transmits television or radio programs, but it can also refer to a device that sends out signals or information, depending on the context in which it is used.
# Yes, the term "cartoon" is ambiguous because it can refer to a style of drawing or animation, a humorous illustration, or even a satirical depiction in print media, depending on the context in which it is used.
# Yes, the term "case" is ambiguous because it can refer to multiple meanings such as a legal case in law, a container for holding items, a situation or instance in general usage, or even a case in medical terminology referring to a patient.
# Yes, the term "celestial body" is ambiguous because it can refer to various types of astronomical objects, such as stars, planets, moons, asteroids, and comets, each with different characteristics and classifications in the field of astronomy.
# No, the term "chemical substance" is not ambiguous because it refers specifically to a material with a definite chemical composition and distinct properties, which is a clear and consistent definition across various scientific contexts.
# Yes, the term "document" is ambiguous because it can refer to a written or printed record in general, but it can also have specific meanings in different contexts, such as a legal document, a digital file, or a document in the context of programming (like a web document).
# Yes, the term "gene" is ambiguous because it can refer to a unit of heredity in biology, but it can also have different meanings in various contexts, such as in genetics, where it may refer to specific sequences of DNA that code for proteins, or in discussions about genetic engineering, where it may imply modifications or manipulations of genetic material.
# No, the term "gridiron football player" is not ambiguous because it specifically refers to a player who participates in gridiron football, which is a distinct type of football played primarily in the United States and Canada. The term does not have multiple meanings or interpretations in different contexts.
# Yes, the term "group" is ambiguous because it can refer to a collection of individuals in a social context, a mathematical concept in group theory, or a category of items in various fields, leading to different interpretations depending on the context.
# Yes, the term "identifier" is ambiguous because it can refer to different concepts in various fields, such as a unique name for a variable in programming, a means of distinguishing entities in databases, or a label used in research to identify subjects or samples.
# Yes, the term "infrastructure" is ambiguous because it can refer to various types of foundational systems and structures, such as transportation networks, utilities, and communication systems, and its specific meaning can change depending on the context in which it is used, such as in urban planning, information technology, or economic development.
# Yes, the term "Legal Case" is ambiguous because it can refer to different types of legal proceedings, such as civil cases, criminal cases, or even specific cases that have become landmark decisions in law, depending on the context in which it is used.
# Yes, the term "mean of transportation" is ambiguous because it can refer to various methods of transport such as cars, buses, trains, bicycles, and airplanes, each serving different purposes and contexts.
# No, the term "motorsport racer" is not ambiguous because it specifically refers to an individual who competes in motorsport events, and its meaning is clear within the context of racing and automotive sports.
# No, the term "natural event" is not ambiguous because it generally refers to occurrences in nature, such as earthquakes, hurricanes, or volcanic eruptions, and does not have multiple meanings or interpretations in different contexts.
# Yes, the term "natural place" is ambiguous because it can refer to different concepts depending on the context, such as a location in nature, a philosophical idea about the inherent state of beings, or even a term used in environmental discussions to describe habitats.
# No, the term "organisation member" is not ambiguous because it clearly refers to an individual who is part of a specific organisation, and its meaning does not change based on context or field.
# No, the term "periodical literature" is not ambiguous because it specifically refers to publications that are released at regular intervals, such as journals, magazines, and newspapers, and does not have multiple meanings or interpretations in different contexts.
# Yes, the term "project" is ambiguous because it can refer to a planned undertaking or task in various contexts, such as a school assignment, a business initiative, or a construction endeavor, and its meaning can change depending on the field in which it is used.
# Yes, the term "race" is ambiguous because it can refer to a competition of speed (such as a running race), a category of people based on shared physical or social qualities (such as racial identity), or even a classification in biology (such as a subspecies). Each meaning varies significantly depending on the context in which it is used.
# Yes, the term "region" is ambiguous because it can refer to different concepts depending on the context, such as a geographical area, a specific administrative division, or a sector in a field like biology or medicine.
# Yes, the term "route of transportation" is ambiguous because it can refer to different types of pathways or methods for moving goods or people, such as a road, rail, air, or water route, and its meaning can vary depending on the context in which it is used.
# No, the term "societal event" is not ambiguous because it generally refers to occurrences or happenings that impact society as a whole, such as festivals, protests, or significant social changes, and does not have multiple meanings or interpretations in different contexts.
# Yes, the term "sports club" is ambiguous because it can refer to different types of organizations, such as a facility for playing various sports, a social club for sports enthusiasts, or a team that competes in a specific sport, depending on the context in which it is used.
# Yes, the term "sports team season" is ambiguous because it can refer to different contexts such as the specific competitive period for a particular sport (e.g., football season, basketball season) or the overall duration of a team's activities, including pre-season and post-season events, which can vary significantly between different sports and leagues.
# Yes, the term "tournament" is ambiguous because it can refer to different types of competitions in various contexts, such as a sports tournament (like a football or basketball competition), a gaming tournament (like esports), or even a medieval tournament involving knights and jousting. Each context gives the term a distinct meaning.
# Yes, the term "unit of work" is ambiguous because it can refer to different concepts in various fields; for example, in physics, it often refers to the amount of energy transferred when a force is applied over a distance, while in project management, it can refer to a specific task or deliverable within a project.
# Yes, the term "work" is ambiguous because it can refer to various concepts such as employment or labor in a professional context, the act of performing tasks or activities, or even a mathematical term related to energy and force in physics.
# No, the term "flowering plant" is not ambiguous because it specifically refers to a category of plants that produce flowers and seeds, which is a clear and defined meaning in botany.
# No, the term "clerical administrative region" is not ambiguous because it refers specifically to a defined area or division related to clerical and administrative functions, and does not have multiple meanings or interpretations in different contexts.
# No, the term "Gnetophytes" is not ambiguous because it specifically refers to a group of seed plants that includes three families: Gnetaceae, Ephedraceae, and Welwitschiaceae. In the context of botany, it has a clear and defined meaning without multiple interpretations.
# No, the term "conifer" is not ambiguous because it specifically refers to a group of trees and shrubs that produce cones and have needle-like leaves, primarily belonging to the class Pinopsida. There are no multiple meanings or contexts that significantly alter its definition.
# No, the term "inline hockey league" is not ambiguous because it specifically refers to a league that organizes and promotes inline hockey, a sport played on inline skates. There are no multiple meanings or contexts that significantly alter its interpretation.
# Yes, the term "image" is ambiguous because it can refer to a visual representation such as a photograph or graphic, but it can also mean a mental representation or concept in psychology, or even a brand's public perception in marketing contexts.

# %% [markdown]
# Check which class names are ambiguous or not using the dictionary Wordnet

# %%
# Iterating through the names
for class_name in class_names:

    # Requesting
    ambiguity_dict, ambiguity_type = check_ambiguity_dictionary_approach(
        class_name["className"]["value"]
    )

    # Updating
    class_ambiguity_comparison[class_name["className"]["value"]][
        "dictionary"
    ] = ambiguity_type

    # Printing according to the return values
    print(
        f"Class name '{class_name["className"]["value"]}':\n{ambiguity_dict} -> is {ambiguity_type}"
    )
# Out:
# Class name 'company':
# {'company': 10} -> is Ambiguous
# Class name 'activity':
# {'activity': 6} -> is Ambiguous
# Class name 'name':
# {'name': 15} -> is Ambiguous
# Class name 'person':
# {'person': 3} -> is Ambiguous
# Class name 'actor':
# {'actor': 2} -> is Ambiguous
# Class name 'place':
# {'place': 32} -> is Ambiguous
# Class name 'publisher':
# {'publisher': 3} -> is Ambiguous
# Class name 'genre':
# {'genre': 4} -> is Ambiguous
# Class name 'language':
# {'language': 6} -> is Ambiguous
# Class name 'department':
# {'department': 3} -> is Ambiguous
# Class name 'software':
# {'software': 1} -> is Non-Ambiguous
# Class name 'school':
# {'school': 10} -> is Ambiguous
# Class name 'type':
# {'type': 8} -> is Ambiguous
# Class name 'non-profit organisation':
# {'non': 1, 'profit': 4, 'organisation': 7} -> is Ambiguous
# Class name 'agent':
# {'agent': 6} -> is Ambiguous
# Class name 'Biomolecule':
# {'Biomolecule': 0} -> is Ambiguous
# Class name 'broadcaster':
# {'broadcaster': 2} -> is Ambiguous
# Class name 'cartoon':
# {'cartoon': 3} -> is Ambiguous
# Class name 'case':
# {'case': 22} -> is Ambiguous
# Class name 'celestial body':
# {'celestial body': 1} -> is Non-Ambiguous
# Class name 'chemical substance':
# {'chemical substance': 1} -> is Non-Ambiguous
# Class name 'document':
# {'document': 6} -> is Ambiguous
# Class name 'gene':
# {'gene': 1} -> is Non-Ambiguous
# Class name 'gridiron football player':
# {'gridiron': 2, 'football': 2, 'player': 5} -> is Ambiguous
# Class name 'group':
# {'group': 5} -> is Ambiguous
# Class name 'identifier':
# {'identifier': 1} -> is Non-Ambiguous
# Class name 'infrastructure':
# {'infrastructure': 2} -> is Ambiguous
# Class name 'Legal Case':
# {'legal': 5, 'case': 22} -> is Ambiguous
# Class name 'mean of transportation':
# {'mean': 16, 'of': 0, 'transportation': 6} -> is Ambiguous
# Class name 'motorsport racer':
# {'motorsport': 0, 'racer': 4} -> is Ambiguous
# Class name 'natural event':
# {'natural event': 1} -> is Non-Ambiguous
# Class name 'natural place':
# {'natural': 13, 'place': 32} -> is Ambiguous
# Class name 'Organisation member':
# {'organisation': 7, 'member': 5} -> is Ambiguous
# Class name 'periodical literature':
# {'periodical': 2, 'literature': 4} -> is Ambiguous
# Class name 'project':
# {'project': 14} -> is Ambiguous
# Class name 'race':
# {'race': 10} -> is Ambiguous
# Class name 'region':
# {'region': 5} -> is Ambiguous
# Class name 'route of transportation':
# {'route': 5, 'of': 0, 'transportation': 6} -> is Ambiguous
# Class name 'societal event':
# {'societal': 1, 'event': 4} -> is Ambiguous
# Class name 'sports club':
# {'sports': 9, 'club': 11} -> is Ambiguous
# Class name 'sports team season':
# {'sports': 9, 'team': 3, 'season': 6} -> is Ambiguous
# Class name 'tournament':
# {'tournament': 2} -> is Ambiguous
# Class name 'unit of work':
# {'unit': 6, 'of': 0, 'work': 34} -> is Ambiguous
# Class name 'work':
# {'work': 34} -> is Ambiguous
# Class name 'flowering plant':
# {'flowering plant': 1} -> is Non-Ambiguous
# Class name 'clerical administrative region':
# {'clerical': 3, 'administrative': 1, 'region': 5} -> is Ambiguous
# Class name 'Gnetophytes':
# {'Gnetophytes': 0} -> is Ambiguous
# Class name 'conifer':
# {'conifer': 1} -> is Non-Ambiguous
# Class name 'inline hockey league':
# {'inline': 0, 'hockey': 2, 'league': 4} -> is Ambiguous
# Class name 'image':
# {'image': 11} -> is Ambiguous

# %%
# Converting the dictionary to dataframe
class_ambiguity_comparison_df = pd.DataFrame.from_dict(class_ambiguity_comparison, orient='index').reset_index()

# Renaming
class_ambiguity_comparison_df.columns = ['class_name', 'llm', 'dictionary']

# Calculating in how many class names agree on the ambiguity estimation
class_agreement = class_ambiguity_comparison_df[class_ambiguity_comparison_df["llm"] == class_ambiguity_comparison_df["dictionary"]]["class_name"].count()

print(f"The two approaches agree in {class_agreement} class names")
# Out:
# The two approaches agree in 36 class names

# %% [markdown]
# Show cases where the two approaches agree on the ambiguity of the class names

# %%
print("Cases where the two approaches agree:")
display(class_ambiguity_comparison_df[class_ambiguity_comparison_df["llm"] == class_ambiguity_comparison_df["dictionary"]])
# Out:
# Cases where the two approaches agree:
#                  class_name            llm     dictionary
# 0                   company      Ambiguous      Ambiguous
# 1                  activity      Ambiguous      Ambiguous
# 2                      name      Ambiguous      Ambiguous
# 4                     actor      Ambiguous      Ambiguous
# 5                     place      Ambiguous      Ambiguous
# 6                 publisher      Ambiguous      Ambiguous
# 7                     genre      Ambiguous      Ambiguous
# 8                  language      Ambiguous      Ambiguous
# 9                department      Ambiguous      Ambiguous
# 10                 software  Non-Ambiguous  Non-Ambiguous
# 11                   school      Ambiguous      Ambiguous
# 12                     type      Ambiguous      Ambiguous
# 14                    agent      Ambiguous      Ambiguous
# 16              broadcaster      Ambiguous      Ambiguous
# 17                  cartoon      Ambiguous      Ambiguous
# 18                     case      Ambiguous      Ambiguous
# 20       chemical substance  Non-Ambiguous  Non-Ambiguous
# 21                 document      Ambiguous      Ambiguous
# 24                    group      Ambiguous      Ambiguous
# 26           infrastructure      Ambiguous      Ambiguous
# 27               Legal Case      Ambiguous      Ambiguous
# 28   mean of transportation      Ambiguous      Ambiguous
# 30            natural event  Non-Ambiguous  Non-Ambiguous
# 31            natural place      Ambiguous      Ambiguous
# 34                  project      Ambiguous      Ambiguous
# 35                     race      Ambiguous      Ambiguous
# 36                   region      Ambiguous      Ambiguous
# 37  route of transportation      Ambiguous      Ambiguous
# 39              sports club      Ambiguous      Ambiguous
# 40       sports team season      Ambiguous      Ambiguous
# 41               tournament      Ambiguous      Ambiguous
# 42             unit of work      Ambiguous      Ambiguous
# 43                     work      Ambiguous      Ambiguous
# 44          flowering plant  Non-Ambiguous  Non-Ambiguous
# 47                  conifer  Non-Ambiguous  Non-Ambiguous
# 49                    image      Ambiguous      Ambiguous

# %% [markdown]
# Show cases where the two approaches do not agree on the ambiguity of the class names

# %%
print("Cases where the two approaches do not agree:")
display(class_ambiguity_comparison_df[class_ambiguity_comparison_df["llm"] != class_ambiguity_comparison_df["dictionary"]])
# Out:
# Cases where the two approaches do not agree:
#                         class_name            llm     dictionary
# 3                           person  Non-Ambiguous      Ambiguous
# 13         non-profit organisation  Non-Ambiguous      Ambiguous
# 15                     Biomolecule  Non-Ambiguous      Ambiguous
# 19                  celestial body      Ambiguous  Non-Ambiguous
# 22                            gene      Ambiguous  Non-Ambiguous
# 23        gridiron football player  Non-Ambiguous      Ambiguous
# 25                      identifier      Ambiguous  Non-Ambiguous
# 29                motorsport racer  Non-Ambiguous      Ambiguous
# 32             Organisation member  Non-Ambiguous      Ambiguous
# 33           periodical literature  Non-Ambiguous      Ambiguous
# 38                  societal event  Non-Ambiguous      Ambiguous
# 45  clerical administrative region  Non-Ambiguous      Ambiguous
# 46                     Gnetophytes  Non-Ambiguous      Ambiguous
# 48            inline hockey league  Non-Ambiguous      Ambiguous

# %% [markdown]
# - #### **Quality Assessment on Property Names**

# %% [markdown]
# Obtain the property names

# %%
# Getting the property names
property_names = get_property_names(sparql)

# Creating a dictionary to compare the results between the approaches
property_ambiguity_comparison = {property_name["propertyName"]["value"]:{} for property_name in property_names}

# %% [markdown]
# Check which property names are ambiguous or not using ChatGPT

# %%
# Iterating through the names
for property_name in property_names:

    # Requesting
    response = check_ambiguity_llm_approach(
        property_name["propertyName"]["value"],
        openai_key,
    )

    # Updating
    property_ambiguity_comparison[property_name["propertyName"]["value"]]["llm"] = (
        "Ambiguous" if "Yes" in response else "Non-Ambiguous"
    )

    print(response)
# Out:
# Yes, the term "name" is ambiguous because it can refer to a person's name, a brand name, a title of a work, or even a designation for a specific object or concept, depending on the context in which it is used.
# No, the term "sec cik" is not ambiguous. It appears to be a specific term that does not have widely recognized multiple meanings or interpretations in different contexts or fields.
# Yes, the term "location" is ambiguous because it can refer to a physical place, a position in a geographical context, or even a specific point in a digital context, such as a location in a database or a file system.
# No, the term "relates an entity to the populated place in which it is located" is not ambiguous because it has a specific meaning in the context of geography or data representation, referring to the relationship between an entity (like a business or landmark) and its geographical location.
# No, the term "birth place" is not ambiguous because it specifically refers to the location where a person was born, and its meaning is consistent across different contexts.
# Yes, the term "death place" is ambiguous because it can refer to the location where a person dies, but it may also imply a specific cultural or legal context, such as a designated area for burial or a place associated with death in literature or art.
# No, the term "death date" is not ambiguous because it specifically refers to the date on which a person or entity dies, and it does not have multiple meanings or interpretations in different contexts.
# No, the term "death" is not ambiguous because it generally refers to the cessation of life and does not have multiple meanings or interpretations in common usage.
# No, the term "birth date" is not ambiguous because it specifically refers to the date on which a person was born, and it does not have multiple meanings or interpretations in different contexts.
# No, the term "birth" is not ambiguous because it specifically refers to the process of being born or the act of giving birth, and it does not have multiple meanings or interpretations in different contexts.
# No, the term "Wikipage page ID" is not ambiguous because it specifically refers to a unique identifier assigned to a page on Wikipedia, and its meaning is consistent across the context of Wikipedia and its related systems.
# No, the term "Wikipage revision ID" is not ambiguous because it specifically refers to a unique identifier assigned to a particular version of a page on Wikipedia, and its meaning is consistent across the context of Wikipedia and its editing system.
# No, the term "link from a Wikipage to another Wikipage" is not ambiguous because it specifically refers to a hyperlink that connects one Wikipedia page to another, and its meaning is clear and consistent within the context of web navigation and online encyclopedias.
# No, the term "wikilink" is not ambiguous because it specifically refers to a hyperlink that connects to a page within a wiki, and its meaning is consistent across contexts related to wikis and online collaborative platforms.
# No, the term "link from a Wikipage to an external page" is not ambiguous because it specifically refers to a hyperlink that directs users from a Wikipedia article to a different website, and its meaning is clear within the context of web navigation and online content.
# Yes, the term "reference" is ambiguous because it can mean different things in various contexts, such as a citation in academic writing, a mention of something in conversation, or a source of information in research.
# No, the term "Wikipage redirect" is not ambiguous because it specifically refers to a feature in Wikipedia that automatically sends users from one page to another. There are no multiple meanings or contexts that significantly alter its interpretation within the realm of online content management.
# Yes, the term "redirect" is ambiguous because it can refer to different actions in various contexts, such as redirecting a web page in internet technology, redirecting a conversation in communication, or redirecting a vehicle in navigation.
# Yes, the term "Wikipage disambiguates" is ambiguous because "disambiguates" can refer to the process of clarifying multiple meanings of a term or concept within a Wikipedia page, but it can also imply different methods or contexts in which disambiguation occurs, such as in linguistics, programming, or information retrieval.
# Yes, the term "selection year" is ambiguous because it can refer to different contexts such as the year in which students are selected for admission to a school or university, the year in which candidates are chosen for a job position, or even the year in which a particular selection process occurs in various competitions or awards.
# Yes, the term "selector" is ambiguous because it can refer to different concepts in various contexts, such as a CSS selector in web development, which is used to select elements in a document, or a selector in programming that determines which items to choose from a set, or even a selector in a user interface that allows users to choose options.
# Yes, the term "selenium" is ambiguous because it can refer to a chemical element (Se) used in various industrial applications, or it can refer to a popular open-source software testing framework used for automating web applications.
# Yes, the term "Selenium iu" is ambiguous because "Selenium" can refer to a chemical element used in various fields such as chemistry and nutrition, while "iu" could refer to "international units," which is a measure used in pharmacology and nutrition. The combination of these terms can lead to different interpretations depending on the context in which they are used.
# Yes, the term "selenium mg" is ambiguous because it can refer to the measurement of selenium in milligrams, which is relevant in nutrition and health contexts, or it could also refer to selenium as a chemical element in scientific discussions, where "mg" indicates a quantity but does not specify the context.
# Yes, the term "selenium ug" is ambiguous because "selenium" can refer to a chemical element (Se) used in various scientific contexts, while "ug" could stand for micrograms, a unit of measurement, or it could refer to something else entirely depending on the context, such as a specific usage in a particular field like nutrition or chemistry.
# Yes, the term "selenium μg" is ambiguous because "selenium" can refer to the chemical element with the symbol Se, which is essential for human health, while "μg" (microgram) is a unit of measurement that can apply to various substances, leading to uncertainty about the context in which selenium is being measured or discussed.
# Yes, the term "self-dual" is ambiguous because it can have different meanings in various fields such as mathematics, computer science, and logic. In mathematics, it often refers to a property of certain structures where an object is isomorphic to its dual, while in computer science, it can refer to a type of data structure that is its own dual representation.
# No, the term "self-propelled" is not ambiguous because it specifically refers to a mechanism or vehicle that moves by its own power without external assistance, and its meaning is consistent across contexts.
# No, the term "self-titled" is not ambiguous because it specifically refers to an album, book, or work that shares the same name as the artist or creator. There is a clear and consistent meaning associated with this term in the context of music and literature.
# No, the term "selfie camera" is not ambiguous because it specifically refers to a type of camera designed for taking self-portraits, typically used with a front-facing lens on smartphones or dedicated cameras. Its meaning is clear and does not change across different contexts or fields.
# No, the term "selfref" is not ambiguous. It typically refers to "self-reference," which is a concept in various fields such as linguistics, logic, and computer science, where an entity refers to itself. The meaning is generally consistent across these contexts, making it clear and unambiguous.
# Yes, the term "Selke" is ambiguous because it can refer to different things depending on the context; for example, it can refer to the Selke Trophy in hockey, awarded to the best defensive forward, or it can refer to a surname of various individuals, including athletes and public figures.
# No, the term "seller" is not ambiguous because it generally refers to a person or entity that sells goods or services, and its meaning is consistent across different contexts and industries.
# Yes, the term "selsoviet type" is ambiguous because it can refer to different types of rural administrative divisions in various countries, particularly in the former Soviet Union, and its specific meaning may vary depending on the historical and geographical context in which it is used.
# Yes, the term "sem" is ambiguous because it can refer to different concepts in various contexts, such as "sem" being short for "semester" in education, "sem" as an abbreviation for "semantic" in linguistics or computer science, or even "sem" as a term in finance referring to "semiconductor."
# Yes, the term "semi" is ambiguous because it can refer to different concepts depending on the context, such as "semi" meaning half in mathematics, a type of truck (semi-trailer), or a prefix in words like "semicircle" or "semiconductor."
# No, the term "semi1 team" is not ambiguous. It appears to refer to a specific team, likely in a sports context, and does not have multiple meanings or interpretations in common usage.
# Yes, the term "semi1 winner" is ambiguous because it can refer to the winner of a semi-final match in various sports or competitions, but the specific context (such as the sport or event) is not clear, leading to multiple interpretations.
# No, the term "semi2 team" is not ambiguous. It appears to refer to a specific team or group, likely within a particular context or organization, and does not have multiple meanings or interpretations in common usage.
# Yes, the term "semi2 winner" is ambiguous because it can refer to the winner of a specific semifinal match in a tournament (often denoted as "semi-final 2") or it could be interpreted in different contexts, such as in sports or competitions, where the meaning of "winner" can vary based on the rules or structure of the event.
# Yes, the term "semi-amp" is ambiguous because it can refer to different concepts depending on the context. In electronics, it might refer to a semi-amplifier, while in other contexts, it could relate to a partial or half measurement of amperage.
# No, the term "semi-final-alt" is not ambiguous because it specifically refers to an alternative format or version of a semi-final event, typically in a sports or competition context, and does not have multiple meanings or interpretations in different contexts.
# No, the term "semi-final-game-score" is not ambiguous because it specifically refers to the score of a semi-final game in a sports context, and its meaning is clear and consistent within that context.
# No, the term "semi-final-loser" is not ambiguous because it specifically refers to a participant in a tournament who loses in the semi-final round, and its meaning is clear and consistent across contexts.
# No, the term "semi-final-winner" is not ambiguous because it specifically refers to the individual or team that wins a semi-final match in a tournament, and its meaning is clear and consistent across contexts related to competitive events.
# No, the term "semi-finalists" is not ambiguous because it specifically refers to individuals or teams that have advanced to the semi-finals in a competition, and its meaning is consistent across different contexts, primarily in sports and contests.
# Yes, the term "semi-official" is ambiguous because it can refer to something that is partially authorized or recognized by an official body, but the level of authority or recognition can vary significantly depending on the context in which it is used, such as in government, business, or social settings.
# No, the term "SemiArena" is not ambiguous. It appears to refer to a specific concept or product, likely related to a particular field or industry, and does not have multiple meanings or interpretations in common usage.
# Yes, the term "semicha" is ambiguous because it can refer to different concepts in various contexts, such as a rabbinical ordination in Jewish tradition or a term used in different religious or philosophical discussions.
# No, the term "SemiCity" is not ambiguous. It appears to refer to a specific concept or name, likely related to urban planning or a particular project, without multiple meanings or interpretations in different contexts.

# %% [markdown]
# Check which property names are ambiguous or not using the dictionary Wordnet

# %%
# Iterating through the names
for property_name in property_names:

    # Requesting
    ambiguity_dict, ambiguity_type = check_ambiguity_dictionary_approach(
        property_name["propertyName"]["value"]
    )

    # Updating
    property_ambiguity_comparison[property_name["propertyName"]["value"]][
        "dictionary"
    ] = ambiguity_type

    # Printing according to the return values
    print(
        f"Property name '{property_name["propertyName"]["value"]}':\n{ambiguity_dict} -> is {ambiguity_type}"
    )
# Out:
# Property name 'name':
# {'name': 15} -> is Ambiguous
# Property name 'sec cik':
# {'sec': 4, 'cik': 0} -> is Ambiguous
# Property name 'location':
# {'location': 4} -> is Ambiguous
# Property name 'Relates an entity to the populated place in which it is located.':
# {'relates': 5, 'an': 1, 'entity': 1, 'to': 0, 'the': 0, 'populated': 3, 'place': 32, 'in': 7, 'which': 0, 'it': 1, 'is': 13, 'located': 5} -> is Ambiguous
# Property name 'birth place':
# {'birth': 6, 'place': 32} -> is Ambiguous
# Property name 'death place':
# {'death': 8, 'place': 32} -> is Ambiguous
# Property name 'death date':
# {'death': 8, 'date': 13} -> is Ambiguous
# Property name 'death':
# {'death': 8} -> is Ambiguous
# Property name 'birth date':
# {'birth': 6, 'date': 13} -> is Ambiguous
# Property name 'birth':
# {'birth': 6} -> is Ambiguous
# Property name 'Wikipage page ID':
# {'wikipage': 0, 'page': 9, 'id': 3} -> is Ambiguous
# Property name 'Wikipage revision ID':
# {'wikipage': 0, 'revision': 3, 'id': 3} -> is Ambiguous
# Property name 'Link from a Wikipage to another Wikipage':
# {'link': 13, 'from': 0, 'a': 7, 'wikipage': 0, 'to': 0, 'another': 1} -> is Ambiguous
# Property name 'wikilink':
# {'wikilink': 0} -> is Ambiguous
# Property name 'Link from a Wikipage to an external page':
# {'link': 13, 'from': 0, 'a': 7, 'wikipage': 0, 'to': 0, 'an': 1, 'external': 5, 'page': 9} -> is Ambiguous
# Property name 'reference':
# {'reference': 11} -> is Ambiguous
# Property name 'Wikipage redirect':
# {'wikipage': 0, 'redirect': 1} -> is Ambiguous
# Property name 'redirect':
# {'redirect': 1} -> is Non-Ambiguous
# Property name 'Wikipage disambiguates':
# {'wikipage': 0, 'disambiguates': 1} -> is Ambiguous
# Property name 'selection year':
# {'selection': 5, 'year': 4} -> is Ambiguous
# Property name 'selector':
# {'selector': 2} -> is Ambiguous
# Property name 'selenium':
# {'selenium': 1} -> is Non-Ambiguous
# Property name 'Selenium iu':
# {'selenium': 1, 'iu': 0} -> is Ambiguous
# Property name 'selenium mg':
# {'selenium': 1, 'mg': 2} -> is Ambiguous
# Property name 'selenium ug':
# {'selenium': 1, 'ug': 0} -> is Ambiguous
# Property name 'selenium μg':
# {'selenium': 1, 'μg': 0} -> is Ambiguous
# Property name 'self-dual':
# {'self': 3, 'dual': 3} -> is Ambiguous
# Property name 'self-propelled':
# {'self': 3, 'propelled': 2} -> is Ambiguous
# Property name 'self-titled':
# {'self': 3, 'titled': 3} -> is Ambiguous
# Property name 'Selfie camera':
# {'selfie': 0, 'camera': 2} -> is Ambiguous
# Property name 'selfref':
# {'selfref': 0} -> is Ambiguous
# Property name 'Selke':
# {'Selke': 0} -> is Ambiguous
# Property name 'seller':
# {'seller': 1} -> is Non-Ambiguous
# Property name 'selsoviet type':
# {'selsoviet': 0, 'type': 8} -> is Ambiguous
# Property name 'sem':
# {'sem': 0} -> is Ambiguous
# Property name 'semi':
# {'semi': 3} -> is Ambiguous
# Property name 'semi1 team':
# {'semi1 team': 3} -> is Ambiguous
# Property name 'semi1 winner':
# {'semi1 winner': 3} -> is Ambiguous
# Property name 'semi2 team':
# {'semi2 team': 3} -> is Ambiguous
# Property name 'semi2 winner':
# {'semi2 winner': 3} -> is Ambiguous
# Property name 'semi-amp':
# {'semi': 3, 'amp': 2} -> is Ambiguous
# Property name 'semi-final-alt':
# {'semi': 3, 'final': 5, 'alt': 1} -> is Ambiguous
# Property name 'semi-final-game-score':
# {'semi': 3, 'final': 5, 'game': 14, 'score': 18} -> is Ambiguous
# Property name 'semi-final-loser':
# {'semi': 3, 'final': 5, 'loser': 3} -> is Ambiguous
# Property name 'semi-final-winner':
# {'semi': 3, 'final': 5, 'winner': 3} -> is Ambiguous
# Property name 'semi-finalists':
# {'semi': 3, 'finalists': 1} -> is Ambiguous
# Property name 'semi-official':
# {'semi': 3, 'official': 7} -> is Ambiguous
# Property name 'SemiArena':
# {'SemiArena': 0} -> is Ambiguous
# Property name 'semicha':
# {'semicha': 0} -> is Ambiguous
# Property name 'SemiCity':
# {'SemiCity': 0} -> is Ambiguous

# %%
# Converting the dictionary to dataframe
property_ambiguity_comparison_df = pd.DataFrame.from_dict(property_ambiguity_comparison, orient='index').reset_index()

# Renaming
property_ambiguity_comparison_df.columns = ['property_name', 'llm', 'dictionary']

# Calculating in how many class names agree on the ambiguity estimation
property_agreement = property_ambiguity_comparison_df[property_ambiguity_comparison_df["llm"] == property_ambiguity_comparison_df["dictionary"]]["property_name"].count()

print(f"The two approaches agree in {property_agreement} class names")
# Out:
# The two approaches agree in 22 class names

# %% [markdown]
# Show cases where the two approaches agree on the ambiguity of the property names

# %%
print("Cases where the two approaches agree:")
display(property_ambiguity_comparison_df[property_ambiguity_comparison_df["llm"] == property_ambiguity_comparison_df["dictionary"]])
# Out:
# Cases where the two approaches agree:
#              property_name            llm     dictionary
# 0                     name      Ambiguous      Ambiguous
# 2                 location      Ambiguous      Ambiguous
# 5              death place      Ambiguous      Ambiguous
# 15               reference      Ambiguous      Ambiguous
# 18  Wikipage disambiguates      Ambiguous      Ambiguous
# 19          selection year      Ambiguous      Ambiguous
# 20                selector      Ambiguous      Ambiguous
# 22             Selenium iu      Ambiguous      Ambiguous
# 23             selenium mg      Ambiguous      Ambiguous
# 24             selenium ug      Ambiguous      Ambiguous
# 25             selenium μg      Ambiguous      Ambiguous
# 26               self-dual      Ambiguous      Ambiguous
# 31                   Selke      Ambiguous      Ambiguous
# 32                  seller  Non-Ambiguous  Non-Ambiguous
# 33          selsoviet type      Ambiguous      Ambiguous
# 34                     sem      Ambiguous      Ambiguous
# 35                    semi      Ambiguous      Ambiguous
# 37            semi1 winner      Ambiguous      Ambiguous
# 39            semi2 winner      Ambiguous      Ambiguous
# 40                semi-amp      Ambiguous      Ambiguous
# 46           semi-official      Ambiguous      Ambiguous
# 48                 semicha      Ambiguous      Ambiguous

# %% [markdown]
# Show cases where the two approaches do not agree on the ambiguity of the property names

# %%
print("Cases where the two approaches do not agree:")
display(property_ambiguity_comparison_df[property_ambiguity_comparison_df["llm"] != property_ambiguity_comparison_df["dictionary"]])
# Out:
# Cases where the two approaches do not agree:
#                                         property_name            llm  \
# 1                                             sec cik  Non-Ambiguous
# 3   Relates an entity to the populated place in wh...  Non-Ambiguous
# 4                                         birth place  Non-Ambiguous
# 6                                          death date  Non-Ambiguous
# 7                                               death  Non-Ambiguous
# 8                                          birth date  Non-Ambiguous
# 9                                               birth  Non-Ambiguous
# 10                                   Wikipage page ID  Non-Ambiguous
# 11                               Wikipage revision ID  Non-Ambiguous
# 12           Link from a Wikipage to another Wikipage  Non-Ambiguous
# 13                                           wikilink  Non-Ambiguous
# 14           Link from a Wikipage to an external page  Non-Ambiguous
# 16                                  Wikipage redirect  Non-Ambiguous
# 17                                           redirect      Ambiguous
# 21                                           selenium      Ambiguous
# 27                                     self-propelled  Non-Ambiguous
# 28                                        self-titled  Non-Ambiguous
# 29                                      Selfie camera  Non-Ambiguous
# 30                                            selfref  Non-Ambiguous
# 36                                         semi1 team  Non-Ambiguous
# 38                                         semi2 team  Non-Ambiguous
# 41                                     semi-final-alt  Non-Ambiguous
# 42                              semi-final-game-score  Non-Ambiguous
# 43                                   semi-final-loser  Non-Ambiguous
# 44                                  semi-final-winner  Non-Ambiguous
# 45                                     semi-finalists  Non-Ambiguous
# 47                                          SemiArena  Non-Ambiguous
# 49                                           SemiCity  Non-Ambiguous
#
#        dictionary
# 1       Ambiguous
# 3       Ambiguous
# 4       Ambiguous
# 6       Ambiguous
# 7       Ambiguous
# 8       Ambiguous
# 9       Ambiguous
# 10      Ambiguous
# 11      Ambiguous
# 12      Ambiguous
# 13      Ambiguous
# 14      Ambiguous
# 16      Ambiguous
# 17  Non-Ambiguous
# 21  Non-Ambiguous
# 27      Ambiguous
# 28      Ambiguous
# 29      Ambiguous
# 30      Ambiguous
# 36      Ambiguous
# 38      Ambiguous
# 41      Ambiguous
# 42      Ambiguous
# 43      Ambiguous
# 44      Ambiguous
# 45      Ambiguous
# 47      Ambiguous
# 49      Ambiguous

# %% [markdown]
# ### **Task 2**

# %% [markdown]
# Define functions related to finding the equivalent ESCO entities in DBPedia and their associated class

# %%
def read_file(file_path):
    """
    This function used to read and process the CSV file containing the ESCO skill entities.

    :param file_path: The path of the CSV file
    :return: A dataframe containing the content of the file
    """

    # Loading the file
    esco_skills_df = pd.read_csv(file_path)

    # Splitting the 'altLabels' column
    esco_skills_df["ESCO_alt_labels"] = esco_skills_df["altLabels"].apply(
        lambda row: row.split("\n") if pd.notnull(row) else []
    )

    # Renaming
    esco_skills_df.rename(columns={"preferredLabel": "ESCO_label"}, inplace=True)

    # Capitalize the first character of the first word
    esco_skills_df["ESCO_label_Capita_first"] = esco_skills_df["ESCO_label"].apply(lambda row: row.capitalize())

    # Capitalize the first character of each word
    esco_skills_df["ESCO_label_Capital_all"] = esco_skills_df["ESCO_label"].apply(lambda row: row.title())

    return esco_skills_df[["ESCO_label", "ESCO_label_Capita_first", "ESCO_label_Capital_all", "ESCO_alt_labels"]]
    

def find_equivelant_entity(labels):
    """
    This function used to find the equivelant entity and its classes based on its labels.

    :param labels: The label of the entity
    :return: The entity and class names
    """
    
    # Iterating through its labels
    for label in labels:
        
        # Trying to find the entity based on its label
        matches = match_entity(label)

        # Checking if it found an entity
        if matches:

            # Setting up a list to store the classes of the entity
            classes = []

            # Iterating through the results
            for match in matches:

                # Updating
                classes.append(match["className"]["value"])

            return label, classes

    return np.nan, np.nan


def match_entity(label):
    """
    This function used to match and return an entity from DBPedia graph based on a given label.

    :param label: The label to search for
    :return: The matched entity
    """

    # Setting up the query
    sparql.setQuery(
        f"""
        SELECT DISTINCT (STR(?classLabel) AS ?className) WHERE {{
        # ?entity rdfs:label "{label}"@en .
        # ?entity rdf:type ?class .
        # ?class rdfs:label ?classLabel .
        FILTER (LANG(?classLabel) = "en")
        FILTER (STRSTARTS(STR(?entity), "http://dbpedia.org/resource/"))
        FILTER (STRSTARTS(STR(?class), "http://dbpedia.org/ontology/"))
        FILTER NOT EXISTS {{ ?superclass rdfs:subClassOf ?class . ?entity rdf:type ?superclass . }}
    }}
    """
    )

    # Executing the query
    query_results = sparql.query().convert()

    return query_results["results"]["bindings"]

# %% [markdown]
# Read the CSV file containing the ESCO skill entities

# %%
# Loading data
esco_skills_df = read_file("esco_skills_en.csv")

esco_skills_df.head(10)
# Out:
#                                       ESCO_label  \
# 0                                        Haskell
# 1                    sport and exercise medicine
# 2                        Incremental development
# 3  use of special equipment for daily activities
# 4                              sawing techniques
# 5                             cold vulcanisation
# 6                                types of barley
# 7                                       KDevelop
# 8           Absorb (learning management systems)
# 9                          cosmetics ingredients
#
#                          ESCO_label_Capita_first  \
# 0                                        Haskell
# 1                    Sport and exercise medicine
# 2                        Incremental development
# 3  Use of special equipment for daily activities
# 4                              Sawing techniques
# 5                             Cold vulcanisation
# 6                                Types of barley
# 7                                       Kdevelop
# 8           Absorb (learning management systems)
# 9                          Cosmetics ingredients
#
#                           ESCO_label_Capital_all  \
# 0                                        Haskell
# 1                    Sport And Exercise Medicine
# 2                        Incremental Development
# 3  Use Of Special Equipment For Daily Activities
# 4                              Sawing Techniques
# 5                             Cold Vulcanisation
# 6                                Types Of Barley
# 7                                       Kdevelop
# 8           Absorb (Learning Management Systems)
# 9                          Cosmetics Ingredients
#
#                                      ESCO_alt_labels
# 0                                                 []
# 1  [sports injury treatment, sports medicine, exe...
# 2                                                 []
# 3                                                 []
# 4  [sawing technologies, sawing methods, sawing t...
# 5  [using vulcanising solution, tyre repair metho...
# 6  [type of barley, a type of barley, barley type...
# 7  [KDevelop 4.7.0, KDevelop 4.6.0, KDevelop 4.0....
# 8                                                 []
# 9  [cosmetics additives, cosmetics elements, a co...

# %% [markdown]
# Find the equivelant DBPedia entities and their classes

# %%
# Finding the equivelant entities and their classes
esco_skills_df[["DBPedia_entity", "DBPedia_class"]] = esco_skills_df.apply(
    lambda row: pd.Series(
        find_equivelant_entity(
            set(
                [
                    row["ESCO_label"],
                    row["ESCO_label_Capita_first"],
                    row["ESCO_label_Capital_all"]
                ]
            )
        )
    ),
    axis=1,
)

# %%
esco_skills_df.head(10)
# Out:
#                                       ESCO_label  \
# 0                                        Haskell
# 1                    sport and exercise medicine
# 2                        Incremental development
# 3  use of special equipment for daily activities
# 4                              sawing techniques
# 5                             cold vulcanisation
# 6                                types of barley
# 7                                       KDevelop
# 8           Absorb (learning management systems)
# 9                          cosmetics ingredients
#
#                          ESCO_label_Capita_first  \
# 0                                        Haskell
# 1                    Sport and exercise medicine
# 2                        Incremental development
# 3  Use of special equipment for daily activities
# 4                              Sawing techniques
# 5                             Cold vulcanisation
# 6                                Types of barley
# 7                                       Kdevelop
# 8           Absorb (learning management systems)
# 9                          Cosmetics ingredients
#
#                           ESCO_label_Capital_all  \
# 0                                        Haskell
# 1                    Sport And Exercise Medicine
# 2                        Incremental Development
# 3  Use Of Special Equipment For Daily Activities
# 4                              Sawing Techniques
# 5                             Cold Vulcanisation
# 6                                Types Of Barley
# 7                                       Kdevelop
# 8           Absorb (Learning Management Systems)
# 9                          Cosmetics Ingredients
#
#                                      ESCO_alt_labels DBPedia_entity  \
# 0                                                 []        Haskell
# 1  [sports injury treatment, sports medicine, exe...            NaN
# 2                                                 []            NaN
# 3                                                 []            NaN
# 4  [sawing technologies, sawing methods, sawing t...            NaN
# 5  [using vulcanising solution, tyre repair metho...            NaN
# 6  [type of barley, a type of barley, barley type...            NaN
# 7  [KDevelop 4.7.0, KDevelop 4.6.0, KDevelop 4.0....       KDevelop
# 8                                                 []            NaN
# 9  [cosmetics additives, cosmetics elements, a co...            NaN
#
#             DBPedia_class
# 0  [programming language]
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7              [software]
# 8                     NaN
# 9                     NaN

# %% [markdown]
# Define a function asking ChatGPT to judge the accuracy of each entity-class pair

# %%
def evaluate_entity_class_pair(entity, enity_class):
    """
    This function used to determine if the entity-class pair is accurate and valid
    using the ChatGPT LLM and especially the gpt-4o-mini model of it.

    :param entity: The entity of the pair
    :param entity_class: The class of the pair
    :return: Yes or No
    """

    # Setting up the content of the 'system' role
    system_content = f"""
    You are an system that judge if a entity-class pair in a knowledge graph is accurate or not. Your job is to determine if the given class accurately describe the given entity.\n
    Please return "Yes" or "No"
    """

    # Setting up the content of the 'user' role
    user_content = f"""
    Entity: "{entity}"\n\
    Proposed Class: "{enity_class}"
    Question: Does the proposed class "{enity_class}" accurately describe the entity "{entity}"?
    """

    # Requesting
    completion = openai_key.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0,
        messages=[
            {"role": "system", "content": system_content},
            {"role": "user", "content": user_content},
        ],
    )

    return completion.choices[0].message.content

# %% [markdown]
# Request for each entity-class pair

# %%
# Getting only the matched entities
matched_esco_skills_df = esco_skills_df[esco_skills_df["DBPedia_entity"].isna() == False][["DBPedia_entity", "DBPedia_class"]].copy()

# Coverting the dataframe
matched_esco_skills_df = matched_esco_skills_df.explode('DBPedia_class')
matched_esco_skills_df.reset_index(drop=True, inplace=True)

# Requesting
matched_esco_skills_df["is_accurate"] = matched_esco_skills_df.apply(lambda row: evaluate_entity_class_pair(row["DBPedia_entity"], row["DBPedia_class"]), axis=1)

matched_esco_skills_df.head(10)
# Out:
#           DBPedia_entity         DBPedia_class is_accurate
# 0                Haskell  programming language         Yes
# 1               KDevelop              software         Yes
# 2              Geomatics                 sport          No
# 3                Maltego              software         Yes
# 4  Cardiovascular system  anatomical structure         Yes
# 5            Criminology                  book          No
# 6            Criminology            university          No
# 7         Photogrammetry                  work          No
# 8         Photogrammetry           music genre          No
# 9     Forensic pathology                 agent          No

# %% [markdown]
# Show how many entities matched

# %%
print(len(matched_esco_skills_df["DBPedia_entity"].unique()))
# Out:
# 590

# %% [markdown]
# Show how many entity-class pairs are judged to be accurate or inaccurate

# %%
print(f"Accurate: {len(matched_esco_skills_df[matched_esco_skills_df["is_accurate"] == "Yes"])}")

print(f"Inaccurate: {len(matched_esco_skills_df[matched_esco_skills_df["is_accurate"] == "No"])}")
# Out:
# Accurate: 110
# Inaccurate: 668

# %% [markdown]
# Show classes that tend to have the fewest mistakes

# %%
matched_esco_skills_df[matched_esco_skills_df["is_accurate"] == "Yes"].groupby(
    "DBPedia_class"
).agg(Total_Mistakes=("DBPedia_entity", "count")).reset_index().sort_values(
    by="Total_Mistakes", ascending=False
)
# Out:
#             DBPedia_class  Total_Mistakes
# 13               software              45
# 12   programming language              16
# 10      medical specialty              13
# 9                language              12
# 5                 company               4
# 14                  sport               4
# 15        topical concept               4
# 16                website               2
# 6                 disease               2
# 0        academic journal               1
# 7                 fashion               1
# 8   information appliance               1
# 4                    city               1
# 2                  animal               1
# 1    anatomical structure               1
# 3                    book               1
# 11                mineral               1

# %% [markdown]
# Show classes that tend to have the most mistakes

# %%
matched_esco_skills_df[matched_esco_skills_df["is_accurate"] == "No"].groupby(
    "DBPedia_class"
).agg(Total_Mistakes=("DBPedia_entity", "count")).reset_index().sort_values(
    by="Total_Mistakes", ascending=False
)
# Out:
#             DBPedia_class  Total_Mistakes
# 31        person function             145
# 27            music genre             115
# 12                   book              71
# 29           organisation              71
# 50             university              30
# 53                   work              24
# 2                Election              23
# 16                company              22
# 44                  sport              22
# 42               software              16
# 33   programming language              12
# 18                disease              12
# 3                    Food               9
# 30                 person               9
# 32                  place               7
# 5        academic journal               7
# 19                   drug               6
# 13               building               6
# 9    anatomical structure               5
# 17                country               5
# 20           ethnic group               4
# 48        topical concept               4
# 1     Biological database               3
# 7                   agent               2
# 0                    Band               2
# 38          road junction               2
# 26          military unit               2
# 39              scientist               2
# 14      chemical compound               2
# 8                   album               2
# 23               language               2
# 25               magazine               2
# 21               hospital               1
# 15            comic strip               1
# 6   administrative region               1
# 4                Youtuber               1
# 11                   bank               1
# 10                  award               1
# 37                  river               1
# 36           railway line               1
# 35          radio station               1
# 34                protein               1
# 24             lighthouse               1
# 22  information appliance               1
# 28                  nerve               1
# 41         societal event               1
# 45           sports event               1
# 43                species               1
# 40            soccer club               1
# 46        television show               1
# 49                   town               1
# 47     television station               1
# 51                village               1
# 52                website               1
